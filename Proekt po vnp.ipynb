# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data= pd.read_csv('/content/drive/MyDrive/MacroTrends_Data_Download_AMZN.csv')
data
# Out:
#             date      open      high       low     close     volume
# 0     1997-05-16    0.0930    0.0987    0.0852    0.0863  294000000
# 1     1997-05-19    0.0852    0.0883    0.0811    0.0852  122136000
# 2     1997-05-20    0.0863    0.0873    0.0816    0.0816  109344000
# 3     1997-05-21    0.0800    0.0821    0.0686    0.0712  377064000
# 4     1997-05-22    0.0717    0.0722    0.0655    0.0696  235536000
# ...          ...       ...       ...       ...       ...        ...
# 6609  2023-08-22  135.0800  135.6500  133.7300  134.2500   32538896
# 6610  2023-08-23  134.5000  135.9500  133.2200  135.5200   40891685
# 6611  2023-08-24  136.4000  136.7750  131.8300  131.8400   41604225
# 6612  2023-08-25  132.4700  133.8700  130.5800  133.2600   42423587
# 6613  2023-08-28  133.7800  133.9500  131.8500  133.1400   33229929
#
# [6614 rows x 6 columns]

# %%
data.isnull().sum()
# Out:
# date      0
# open      0
# high      0
# low       0
# close     0
# volume    0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6614 entries, 0 to 6613
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    6614 non-null   object
#  1   open    6614 non-null   float64
#  2   high    6614 non-null   float64
#  3   low     6614 non-null   float64
#  4   close   6614 non-null   float64
#  5   volume  6614 non-null   int64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 310.2+ KB

# %%
dataCopy=data[data.date.between("2019-01-01", "2023-08-28")]

# %%
dataCopy
# Out:
#             date      open      high       low     close     volume
# 5442  2019-01-02   73.0840   77.4814   72.8710   76.7716  159662060
# 5443  2019-01-03   75.8179   76.7152   74.6756   74.8338  139511440
# 5444  2019-01-04   76.3162   79.5085   75.7331   78.5802  183651500
# 5445  2019-01-07   79.9230   81.5316   79.2681   81.2797  159864260
# 5446  2019-01-08   83.0345   83.6291   80.6363   82.6300  177628560
# ...          ...       ...       ...       ...       ...        ...
# 6609  2023-08-22  135.0800  135.6500  133.7300  134.2500   32538896
# 6610  2023-08-23  134.5000  135.9500  133.2200  135.5200   40891685
# 6611  2023-08-24  136.4000  136.7750  131.8300  131.8400   41604225
# 6612  2023-08-25  132.4700  133.8700  130.5800  133.2600   42423587
# 6613  2023-08-28  133.7800  133.9500  131.8500  133.1400   33229929
#
# [1172 rows x 6 columns]

# %%
dataCopy.isnull().sum()
# Out:
# date      0
# open      0
# high      0
# low       0
# close     0
# volume    0
# dtype: int64

# %%
dataCopy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1172 entries, 5442 to 6613
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1172 non-null   object
#  1   open    1172 non-null   float64
#  2   high    1172 non-null   float64
#  3   low     1172 non-null   float64
#  4   close   1172 non-null   float64
#  5   volume  1172 non-null   int64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 64.1+ KB

# %%
stats = []
for column in dataCopy:
  if dataCopy[column].dtype != 'object':
    stats.append(dataCopy[column].describe())
pd.DataFrame(stats)
# Out:
#          count          mean           std           min           25%  \
# open    1172.0  1.266017e+02  3.210153e+01  7.308400e+01  9.464817e+01
# high    1172.0  1.281576e+02  3.240063e+01  7.671520e+01  9.563700e+01
# low     1172.0  1.249325e+02  3.169437e+01  7.287100e+01  9.347825e+01
# close   1172.0  1.265557e+02  3.199372e+01  7.483380e+01  9.467025e+01
# volume  1172.0  7.694265e+07  3.357496e+07  1.762674e+07  5.436073e+07
#
#                  50%           75%           max
# open    1.226546e+02  1.588733e+02  1.867502e+02
# high    1.241171e+02  1.604828e+02  1.882007e+02
# low     1.209087e+02  1.566757e+02  1.843954e+02
# close   1.230016e+02  1.587500e+02  1.861222e+02
# volume  6.683688e+07  9.054140e+07  3.113457e+08

# %%
sns.distplot(dataCopy.high)
# Out:
# <Axes: xlabel='high', ylabel='Density'>

# %%
data1= pd.read_csv('/content/drive/MyDrive/esgScore.csv')

# %%
data1
# Out:
#    result__peerGroup  result__symbolSeries__timestamp  \
# 0          Retailing                       1409529600
# 1                NaN                       1412121600
# 2                NaN                       1414800000
# 3                NaN                       1417392000
# 4                NaN                       1420070400
# ..               ...                              ...
# 91               NaN                       1648771200
# 92               NaN                       1651363200
# 93               NaN                       1654041600
# 94               NaN                       1656633600
# 95               NaN                       1659312000
#
#     result__symbolSeries__esgScore  result__symbolSeries__governanceScore  \
# 0                            51.00                                  50.00
# 1                            51.00                                  50.00
# 2                            51.00                                  50.00
# ...

# %%
data1.isnull().sum()
# Out:
# result__peerGroup                         95
# result__symbolSeries__timestamp            0
# result__symbolSeries__esgScore            18
# result__symbolSeries__governanceScore     18
# result__symbolSeries__environmentScore    18
# result__symbolSeries__socialScore         18
# result__peerSeries__timestamp              0
# result__peerSeries__esgScore              17
# result__peerSeries__governanceScore       17
# result__peerSeries__environmentScore      17
# result__peerSeries__socialScore           17
# error                                     96
# dtype: int64

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 12 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   result__peerGroup                       1 non-null      object
#  1   result__symbolSeries__timestamp         96 non-null     int64
#  2   result__symbolSeries__esgScore          78 non-null     float64
#  3   result__symbolSeries__governanceScore   78 non-null     float64
#  4   result__symbolSeries__environmentScore  78 non-null     float64
#  5   result__symbolSeries__socialScore       78 non-null     float64
#  6   result__peerSeries__timestamp           96 non-null     int64
#  7   result__peerSeries__esgScore            79 non-null     float64
#  8   result__peerSeries__governanceScore     79 non-null     float64
#  9   result__peerSeries__environmentScore    79 non-null     float64
# ...

# %%
data1.drop(["result__peerGroup","result__symbolSeries__timestamp","result__symbolSeries__governanceScore","result__symbolSeries__environmentScore","result__symbolSeries__socialScore","result__peerSeries__timestamp","result__peerSeries__governanceScore","result__peerSeries__environmentScore","result__peerSeries__socialScore","error"],axis= 1, inplace = True)

# %%
data1
# Out:
#     result__symbolSeries__esgScore  result__peerSeries__esgScore
# 0                            51.00                     57.272727
# 1                            51.00                     57.357143
# 2                            51.00                     57.357143
# 3                            50.00                     57.267857
# 4                            50.00                     57.250000
# ..                             ...                           ...
# 91                             NaN                           NaN
# 92                           30.23                     16.393158
# 93                             NaN                           NaN
# 94                             NaN                           NaN
# 95                           30.28                     16.178148
#
# [96 rows x 2 columns]

# %%
data1.isnull().sum()
# Out:
# result__symbolSeries__esgScore    18
# result__peerSeries__esgScore      17
# dtype: int64

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 2 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   result__symbolSeries__esgScore  78 non-null     float64
#  1   result__peerSeries__esgScore    79 non-null     float64
# dtypes: float64(2)
# memory usage: 1.6 KB

# %%
Data1=data1.fillna(0)
Data1
# Out:
#     result__symbolSeries__esgScore  result__peerSeries__esgScore
# 0                            51.00                     57.272727
# 1                            51.00                     57.357143
# 2                            51.00                     57.357143
# 3                            50.00                     57.267857
# 4                            50.00                     57.250000
# ..                             ...                           ...
# 91                            0.00                      0.000000
# 92                           30.23                     16.393158
# 93                            0.00                      0.000000
# 94                            0.00                      0.000000
# 95                           30.28                     16.178148
#
# [96 rows x 2 columns]

# %%
Data1.isnull().sum()
# Out:
# result__symbolSeries__esgScore    0
# result__peerSeries__esgScore      0
# dtype: int64

# %%
# !pip install tsfresh
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.3/95.3 kB 1.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.1/169.1 kB 12.9 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
from tsfresh import extract_features

# %%
dataCopy['date'] = pd.to_datetime(dataCopy['date'])
dataCopy.set_index('date', inplace=True)

# %%
y = dataCopy['high']
X = y.copy()

# %%
X= extract_features(dataCopy,
                     column_id="high",
                     pivot=True)
# Out:
# WARNING:tsfresh.feature_extraction.settings:Dependency not available for matrix_profile, this feature will be disabled!
# Feature Extraction: 100%|██████████| 4608/4608 [02:38<00:00, 29.08it/s]

# %%
print(X)
# Out:
#           open__variance_larger_than_standard_deviation  \
# 76.7152                                             0.0
# 77.4814                                             0.0
# 79.2387                                             0.0
# 79.5085                                             0.0
# 80.2712                                             0.0
# ...                                                 ...
# 186.9497                                            0.0
# 187.4131                                            0.0
# 187.5478                                            0.0
# 187.6550                                            0.0
# 188.2007                                            0.0
#
#           open__has_duplicate_max  open__has_duplicate_min  \
# 76.7152                       0.0                      0.0
# 77.4814                       0.0                      0.0
# 79.2387                       0.0                      0.0
# ...

# %%
from tsfresh.utilities.dataframe_functions import impute
impute(X)
# Out:
#           open__variance_larger_than_standard_deviation  \
# 76.7152                                             0.0
# 77.4814                                             0.0
# 79.2387                                             0.0
# 79.5085                                             0.0
# 80.2712                                             0.0
# ...                                                 ...
# 186.9497                                            0.0
# 187.4131                                            0.0
# 187.5478                                            0.0
# 187.6550                                            0.0
# 188.2007                                            0.0
#
#           open__has_duplicate_max  open__has_duplicate_min  \
# 76.7152                       0.0                      0.0
# 77.4814                       0.0                      0.0
# 79.2387                       0.0                      0.0
# ...

# %%
stats = []
for column in data1:
  if data1[column].dtype != 'object':
    stats.append(data1[column].describe())
pd.DataFrame(stats)
# Out:
#                                 count       mean        std        min  \
# result__symbolSeries__esgScore   78.0  44.787821   7.863691  27.280000
# result__peerSeries__esgScore     79.0  48.548445  15.527622  16.178148
#
#                                       25%        50%        75%        max
# result__symbolSeries__esgScore  44.840000  47.280000  49.670000  53.000000
# result__peerSeries__esgScore    54.766841  55.430667  56.208136  57.928571

# %%
from sklearn.model_selection import train_test_split

train, test = train_test_split(dataCopy, test_size = 0.2)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.pairplot(dataCopy)

# %%
train.head(10)
# Out:
#                 open      high       low     close     volume
# date
# 2019-08-28   87.5392   88.1806   86.9930   88.0006   48437860
# 2019-02-07   81.0548   81.0817   79.4541   80.5246   92531780
# 2023-02-23   96.1200   96.4300   93.6700   95.8200   47766736
# 2021-06-24  174.9606  175.8195  171.1303  172.0396   76357980
# 2021-02-19  166.0117  166.2745  161.8976  162.1046   86103680
# 2021-07-08  181.7403  187.5478  180.6210  186.1222  102890780
# 2022-07-05  107.3415  113.8059  106.0687  113.2273   73951638
# 2021-01-27  166.6731  166.9240  159.9687  161.2407   93203160
# 2020-10-16  167.7575  169.5746  157.6204  163.2423  129487060
# 2020-10-30  157.5081  157.9695  150.5873  151.4428  167921620

# %%
test.head(10)
# Out:
#                 open      high       low     close     volume
# date
# 2021-08-16  163.7556  164.6036  160.1707  164.5532   66569880
# 2022-07-20  118.3300  123.1783  118.0357  122.4750   71002065
# 2019-04-16   92.3451   93.2639   92.1780   92.9282   60892360
# 2019-05-30   91.0552   91.2537   90.1743   90.5978   62937000
# 2020-09-04  165.5014  168.6688  155.1827  164.3352  175635080
# 2022-07-19  115.4220  118.6642  113.7560  117.9260   60613080
# 2020-10-29  159.6789  162.4712  157.8199  160.1647  131930580
# 2021-03-18  154.6775  155.4571  150.8866  151.0357   73140540
# 2019-03-06   84.5948   84.6835   83.2136   83.2470   79920020
# 2020-05-21  124.6997  125.9691  121.8336  122.0431  102288060

# %%
x_train = train[['open', 'high', 'low', 'volume']].values
x_test = test[['open', 'high', 'low', 'volume']].values

# %%
y_train = train['high'].values
y_test = test['high'].values

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# 1.0

# %%
plt.title('Linear Regression', color="white")
plt.scatter(y_pred, y_test, color="#94F008")
plt.scatter(y_test, y_test, color="red")
plt.plot(y_test, y_test, color="yellow")
plt.legend(["Predicted_Close", "Actual_Close", "Regression Line"], loc ="lower right", facecolor='black', labelcolor='white')

# %%
dataCopy['high'] = dataCopy['high'].astype(int)
dataCopy['open'] = dataCopy['open'].astype(int)
dataCopy['low'] = dataCopy['low'].astype(int)
dataCopy['close'] = dataCopy['close'].astype(int)

# %%
dataCopy
# Out:
#             open  high  low  close     volume
# date
# 2019-01-02    73    77   72     76  159662060
# 2019-01-03    75    76   74     74  139511440
# 2019-01-04    76    79   75     78  183651500
# 2019-01-07    79    81   79     81  159864260
# 2019-01-08    83    83   80     82  177628560
# ...          ...   ...  ...    ...        ...
# 2023-08-22   135   135  133    134   32538896
# 2023-08-23   134   135  133    135   40891685
# 2023-08-24   136   136  131    131   41604225
# 2023-08-25   132   133  130    133   42423587
# 2023-08-28   133   133  131    133   33229929
#
# [1172 rows x 5 columns]

# %%
#train, test = train_test_split(dataCopy, test_size = 0.2)

# %%
#x_train = train[['open', 'high', 'low', 'volume']].values
#x_test = test[['open', 'high', 'low', 'volume']].values

# %%
#y_train = train['high'].values
#y_test = test['high'].values

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split( dataCopy[dataCopy.columns[:-1]],  dataCopy['high'], test_size=0.2)

# %%
from xgboost import XGBClassifier
model = XGBClassifier(n_estimators=15,max_depth=15,learning_rate =0.01,min_child_weight=5,colsample_bytree=0.3)
model.fit(X_train,Y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-12c46ed7378d> in <cell line: 3>()
#       1 from xgboost import XGBClassifier
#       2 model = XGBClassifier(n_estimators=15,max_depth=15,learning_rate =0.01,min_child_weight=5,colsample_bytree=0.3)
# ----> 3 model.fit(X_train,Y_train)
#
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py in inner_f(*args, **kwargs)
#     618             for k, arg in zip(sig.parameters, args):
#     619                 kwargs[k] = arg
# --> 620             return func(**kwargs)
#     621
#     622         return inner_f
#
# /usr/local/lib/python3.10/dist-packages/xgboost/sklearn.py in fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights, callbacks)
# ...

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import LSTM

model2 = Sequential()

model2.add(Dense(32, input_dim=13, activation='relu'))

model2.add(Dropout(0.2, input_shape=(32,)))

model2.add(Dense(21, activation='relu'))

model2.add(Dropout(0.2, input_shape=(21,)))

model2.add(Dense(15, activation='relu'))

model2.add(Dropout(0.2, input_shape=(15,)))

model2.add(Dense(1, activation='linear'))

# %%
train, test = train_test_split(dataCopy, test_size = 0.2)

# %%
x_train = train[['open', 'high', 'low', 'volume']].values
x_test = test[['open', 'high', 'low', 'volume']].values

# %%
y_train = train['high'].values
y_test = test['high'].values

# %%
x_train.shape
# Out:
# (937, 4)

# %%
model2.compile(loss='mse', optimizer='adam', metrics=['mse','mae'])

# %%
history2 = model2.fit(x_train, y_train, epochs=80, batch_size=15,  verbose=1, validation_split=0.2)
# Out:
# Epoch 1/80
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-62-9e67f14d646f> in <cell line: 1>()
# ----> 1 history2 = model2.fit(x_train, y_train, epochs=80, batch_size=15,  verbose=1, validation_split=0.2)
#
# /usr/local/lib/python3.10/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/engine/training.py in tf__train_function(iterator)
#      13                 try:
#      14                     do_return = True
# ...

# %%
plt.plot(history2.history['loss'])
plt.plot(history2.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
plt.show()

# %%
y2_pred = model2.predict(X_test)

# %%
from sklearn.metrics import r2_score
print("r_square score: ", r2_score(Y_test,y2_pred))
